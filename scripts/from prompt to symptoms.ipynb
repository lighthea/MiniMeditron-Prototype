# %%
from os import listdir
from os.path import isfile, join
import subprocess
patient_folder = "../generated_patients_finetuned/"
onlyfiles = [f for f in listdir(patient_folder) if isfile(join(patient_folder, f))]

# %%
onlyfiles
# Out:
# ['guideline_gc.jsonl_435.json',
#  'guideline_mayo.jsonl_682.json',
#  'guideline_mayo.jsonl_310.json',
#  'guideline_gc.jsonl_709.json',
#  'guideline_gc.jsonl_946.json',
#  'guideline_nice.jsonl_858.json',
#  'guideline_gc.jsonl_414.json',
#  'guideline_rch.jsonl_265.json',
#  'guideline_cdc_diseases.jsonl_15.json',
#  'guideline_gc.jsonl_517.json',
#  'guideline_mayo.jsonl_886.json',
#  'guideline_gc.jsonl_576.json',
#  'guideline_gc.jsonl_398.json',
#  'guideline_nice.jsonl_1543.json',
#  'guideline_mayo.jsonl_238.json',
#  'guideline_mayo.jsonl_863.json',
#  'guideline_gc.jsonl_599.json',
#  'guideline_cdc_diseases.jsonl_3.json',
#  'guideline_rch.jsonl_208.json',
#  'guideline_gc.jsonl_710.json',
#  'guideline_mayo.jsonl_211.json',
#  'guideline_gc.jsonl_53.json',
#  'guideline_rch.jsonl_153.json',
#  'guideline_gc.jsonl_833.json',
#  'guideline_gc.jsonl_826.json',
#  'guideline_mayo.jsonl_288.json',
#  'guideline_rch.jsonl_136.json',
#  'guideline_mayo.jsonl_1096.json',
#  'guideline_cdc_diseases.jsonl_29.json',
#  'guideline_rch.jsonl_276.json',
#  'guideline_nice.jsonl_117.json',
#  'guideline_gc.jsonl_192.json',
#  'guideline_nice.jsonl_1275.json',
#  'guideline_nice.jsonl_1519.json',
#  'guideline_nice.jsonl_1525.json',
#  'guideline_gc.jsonl_327.json',
#  'guideline_nice.jsonl_248.json',
#  'guideline_gc.jsonl_239.json',
#  'guideline_gc.jsonl_178.json',
#  'guideline_mayo.jsonl_932.json',
#  'guideline_gc.jsonl_281.json',
#  'guideline_aafp.jsonl_33.json',
#  'guideline_rch.jsonl_56.json',
#  'guideline_mayo.jsonl_597.json',
#  'guideline_mayo.jsonl_313.json',
#  'guideline_mayo.jsonl_680.json',
#  'guideline_mayo.jsonl_479.json',
#  'guideline_nice.jsonl_1389.json',
#  'guideline_gc.jsonl_688.json',
#  'guideline_mayo.jsonl_855.json',
#  'guideline_nice.jsonl_1619.json',
#  'guideline_gc.jsonl_901.json',
#  'guideline_cdc_diseases.jsonl_26.json',
#  'guideline_mayo.jsonl_610.json',
#  'guideline_gc.jsonl_670.json',
#  'guideline_usp.jsonl_58.json',
#  'guideline_rch.jsonl_158.json',
#  'guideline_mayo.jsonl_876.json',
#  'guideline_rch.jsonl_278.json',
#  'guideline_mayo.jsonl_48.json',
#  'guideline_gc.jsonl_787.json',
#  'guideline_nice.jsonl_301.json',
#  'guideline_mayo.jsonl_492.json',
#  'guideline_nice.jsonl_920.json',
#  'guideline_gc.jsonl_922.json',
#  'guideline_mayo.jsonl_580.json',
#  'guideline_nice.jsonl_141.json',
#  'guideline_nice.jsonl_1634.json',
#  'guideline_gc.jsonl_783.json',
#  'guideline_cdc_diseases.jsonl_23.json',
#  'guideline_rch.jsonl_124.json',
#  'guideline_mayo.jsonl_1080.json',
#  'guideline_nice.jsonl_1322.json',
#  'guideline_mayo.jsonl_138.json',
#  'guideline_mayo.jsonl_172.json',
#  'guideline_nice.jsonl_1571.json',
#  'guideline_mayo.jsonl_737.json',
#  'guideline_usp.jsonl_16.json',
#  'guideline_nice.jsonl_234.json',
#  'guideline_nice.jsonl_1376.json',
#  'guideline_rch.jsonl_256.json',
#  'guideline_nice.jsonl_1306.json',
#  'guideline_gc.jsonl_463.json',
#  'guideline_mayo.jsonl_291.json',
#  'guideline_nice.jsonl_7.json',
#  'guideline_gc.jsonl_632.json',
#  'guideline_mayo.jsonl_511.json',
#  'guideline_nice.jsonl_267.json',
#  'guideline_mayo.jsonl_933.json',
#  'guideline_usp.jsonl_57.json',
#  'guideline_rch.jsonl_372.json',
#  'guideline_nice.jsonl_1348.json',
#  'guideline_gc.jsonl_742.json',
#  'guideline_nice.jsonl_926.json',
#  'guideline_nice.jsonl_1094.json',
#  'guideline_idsa.jsonl_44.json',
#  'guideline_nice.jsonl_723.json',
#  'guideline_nice.jsonl_780.json',
#  'guideline_mayo.jsonl_906.json',
#  'guideline_nice.jsonl_563.json',
#  'guideline_mayo.jsonl_293.json',
#  'guideline_gc.jsonl_849.json',
#  'guideline_mayo.jsonl_360.json',
#  'guideline_nice.jsonl_1157.json',
#  'guideline_rch.jsonl_134.json',
#  'guideline_mayo.jsonl_430.json',
#  'guideline_gc.jsonl_700.json',
#  'guideline_gc.jsonl_198.json',
#  'guideline_mayo.jsonl_640.json',
#  'guideline_gc.jsonl_697.json',
#  'guideline_nice.jsonl_947.json',
#  'guideline_mayo.jsonl_1007.json',
#  'guideline_mayo.jsonl_761.json',
#  'guideline_mayo.jsonl_380.json',
#  'guideline_gc.jsonl_872.json',
#  'guideline_gc.jsonl_734.json',
#  'guideline_rch.jsonl_378.json',
#  'guideline_mayo.jsonl_10.json',
#  'guideline_gc.jsonl_936.json',
#  'guideline_mayo.jsonl_468.json',
#  'guideline_gc.jsonl_385.json',
#  'guideline_nice.jsonl_1481.json',
#  'guideline_gc.jsonl_928.json',
#  'guideline_gc.jsonl_475.json',
#  'guideline_nice.jsonl_1630.json',
#  'guideline_cdc_diseases.jsonl_44.json',
#  'guideline_gc.jsonl_609.json',
#  'guideline_rch.jsonl_339.json',
#  'guideline_aafp.jsonl_25.json',
#  'guideline_mayo.jsonl_644.json',
#  'guideline_nice.jsonl_68.json',
#  'guideline_gc.jsonl_663.json',
#  'guideline_nice.jsonl_232.json',
#  'guideline_gc.jsonl_603.json',
#  'guideline_mayo.jsonl_809.json',
#  'guideline_rch.jsonl_5.json',
#  'guideline_nice.jsonl_1150.json',
#  'guideline_rch.jsonl_271.json',
#  'guideline_mayo.jsonl_405.json',
#  'guideline_nice.jsonl_1365.json',
#  'guideline_mayo.jsonl_870.json',
#  'guideline_mayo.jsonl_130.json',
#  'guideline_mayo.jsonl_191.json',
#  'guideline_mayo.jsonl_1079.json',
#  'guideline_gc.jsonl_5.json',
#  'guideline_mayo.jsonl_899.json',
#  'guideline_gc.jsonl_63.json',
#  'guideline_nice.jsonl_1562.json',
#  'guideline_mayo.jsonl_341.json',
#  'guideline_gc.jsonl_882.json',
#  'guideline_gc.jsonl_265.json',
#  'guideline_rch.jsonl_137.json',
#  'guideline_rch.jsonl_85.json',
#  'guideline_rch.jsonl_326.json',
#  'guideline_gc.jsonl_490.json',
#  'guideline_mayo.jsonl_576.json',
#  'guideline_gc.jsonl_237.json',
#  'guideline_nice.jsonl_191.json',
#  'guideline_mayo.jsonl_258.json',
#  'guideline_mayo.jsonl_419.json',
#  'guideline_rch.jsonl_73.json',
#  'guideline_usp.jsonl_5.json',
#  'guideline_mayo.jsonl_792.json',
#  'guideline_rch.jsonl_207.json',
#  'guideline_mayo.jsonl_327.json',
#  'guideline_nice.jsonl_1623.json',
#  'guideline_cdc_diseases.jsonl_12.json',
#  'guideline_mayo.jsonl_623.json',
#  'guideline_gc.jsonl_87.json',
#  'guideline_rch.jsonl_88.json',
#  'guideline_mayo.jsonl_738.json',
#  'guideline_mayo.jsonl_1009.json',
#  'guideline_mayo.jsonl_542.json',
#  'guideline_gc.jsonl_368.json',
#  'guideline_nice.jsonl_1411.json',
#  'guideline_gc.jsonl_712.json',
#  'guideline_mayo.jsonl_82.json',
#  'guideline_mayo.jsonl_850.json',
#  'guideline_mayo.jsonl_656.json',
#  'guideline_mayo.jsonl_882.json',
#  'guideline_mayo.jsonl_454.json',
#  'guideline_mayo.jsonl_622.json',
#  'guideline_gc.jsonl_506.json',
#  'guideline_mayo.jsonl_353.json',
#  'guideline_nice.jsonl_1208.json',
#  'guideline_gc.jsonl_589.json',
#  'guideline_nice.jsonl_1450.json',
#  'guideline_rch.jsonl_318.json',
#  'guideline_gc.jsonl_188.json',
#  'guideline_nice.jsonl_967.json',
#  'guideline_nice.jsonl_77.json',
#  'guideline_mayo.jsonl_716.json',
#  'guideline_nice.jsonl_981.json',
#  'guideline_gc.jsonl_487.json',
#  'guideline_nice.jsonl_744.json',
#  'guideline_mayo.jsonl_280.json',
#  'guideline_nice.jsonl_1198.json',
#  'guideline_gc.jsonl_466.json',
#  'guideline_nice.jsonl_84.json',
#  'guideline_nice.jsonl_1621.json',
#  'guideline_mayo.jsonl_829.json',
#  'guideline_nice.jsonl_1596.json',
#  'guideline_cdc_diseases.jsonl_14.json',
#  'guideline_rch.jsonl_236.json',
#  'guideline_nice.jsonl_1358.json',
#  'guideline_gc.jsonl_626.json',
#  'guideline_rch.jsonl_317.json',
#  'guideline_cma.jsonl_50.json',
#  'guideline_gc.jsonl_944.json',
#  'guideline_usp.jsonl_33.json',
#  'guideline_rch.jsonl_185.json',
#  'guideline_mayo.jsonl_826.json',
#  'guideline_gc.jsonl_353.json',
#  'guideline_mayo.jsonl_192.json',
#  'guideline_nice.jsonl_671.json',
#  'guideline_nice.jsonl_233.json',
#  'guideline_mayo.jsonl_446.json',
#  'guideline_nice.jsonl_155.json',
#  'guideline_gc.jsonl_615.json',
#  'guideline_mayo.jsonl_275.json',
#  'guideline_rch.jsonl_76.json',
#  'guideline_rch.jsonl_92.json',
#  'guideline_nice.jsonl_845.json',
#  'guideline_gc.jsonl_369.json',
#  'guideline_nice.jsonl_1455.json',
#  'guideline_usp.jsonl_25.json',
#  'guideline_rch.jsonl_115.json',
#  'guideline_gc.jsonl_15.json',
#  'guideline_nice.jsonl_1368.json',
#  'guideline_mayo.jsonl_752.json',
#  'guideline_mayo.jsonl_728.json',
#  'guideline_mayo.jsonl_529.json',
#  'guideline_mayo.jsonl_199.json',
#  'guideline_rch.jsonl_103.json',
#  'guideline_mayo.jsonl_820.json',
#  'guideline_nice.jsonl_742.json',
#  'guideline_gc.jsonl_897.json',
#  'guideline_mayo.jsonl_16.json',
#  'guideline_usp.jsonl_62.json',
#  'guideline_usp.jsonl_84.json',
#  'guideline_usp.jsonl_9.json',
#  'guideline_mayo.jsonl_325.json',
#  'guideline_gc.jsonl_525.json',
#  'guideline_gc.jsonl_948.json',
#  'guideline_nice.jsonl_647.json',
#  'guideline_mayo.jsonl_607.json',
#  'guideline_mayo.jsonl_884.json',
#  'guideline_nice.jsonl_683.json',
#  'guideline_gc.jsonl_366.json',
#  'guideline_gc.jsonl_150.json',
#  'guideline_nice.jsonl_405.json',
#  'guideline_rch.jsonl_130.json',
#  'guideline_mayo.jsonl_665.json',
#  'guideline_mayo.jsonl_831.json',
#  'guideline_gc.jsonl_403.json',
#  'guideline_gc.jsonl_445.json',
#  'guideline_gc.jsonl_765.json',
#  'guideline_nice.jsonl_1356.json',
#  'guideline_gc.jsonl_242.json',
#  'guideline_gc.jsonl_488.json',
#  'guideline_gc.jsonl_3.json',
#  'guideline_gc.jsonl_574.json',
#  'guideline_mayo.jsonl_1052.json',
#  'guideline_gc.jsonl_501.json',
#  'guideline_gc.jsonl_655.json',
#  'guideline_nice.jsonl_929.json',
#  'guideline_nice.jsonl_681.json',
#  'guideline_mayo.jsonl_303.json',
#  'guideline_mayo.jsonl_398.json',
#  'guideline_idsa.jsonl_39.json',
#  'guideline_mayo.jsonl_920.json',
#  'guideline_gc.jsonl_527.json',
#  'guideline_mayo.jsonl_674.json',
#  'guideline_nice.jsonl_1585.json',
#  'guideline_mayo.jsonl_99.json',
#  'guideline_gc.jsonl_866.json',
#  'guideline_mayo.jsonl_672.json',
#  'guideline_nice.jsonl_1605.json',
#  'guideline_gc.jsonl_148.json',
#  'guideline_mayo.jsonl_758.json',
#  'guideline_mayo.jsonl_599.json',
#  'guideline_nice.jsonl_1557.json',
#  'guideline_mayo.jsonl_957.json',
#  'guideline_rch.jsonl_197.json',
#  'guideline_nice.jsonl_148.json',
#  'guideline_mayo.jsonl_602.json',
#  'guideline_gc.jsonl_17.json',
#  'guideline_nice.jsonl_292.json',
#  'guideline_mayo.jsonl_5.json',
#  'guideline_mayo.jsonl_515.json',
#  'guideline_gc.jsonl_154.json',
#  'guideline_nice.jsonl_1343.json',
#  'guideline_nice.jsonl_612.json',
#  'guideline_gc.jsonl_282.json',
#  'guideline_nice.jsonl_11.json',
#  'guideline_nice.jsonl_143.json',
#  'guideline_rch.jsonl_225.json',
#  'guideline_mayo.jsonl_31.json',
#  'guideline_mayo.jsonl_147.json',
#  'guideline_gc.jsonl_127.json',
#  'guideline_nice.jsonl_1338.json',
#  'guideline_nice.jsonl_1380.json',
#  'guideline_nice.jsonl_1048.json',
#  'guideline_mayo.jsonl_61.json',
#  'guideline_aafp.jsonl_11.json',
#  'guideline_nice.jsonl_467.json',
#  'guideline_aafp.jsonl_40.json',
#  'guideline_gc.jsonl_584.json',
#  'guideline_mayo.jsonl_912.json',
#  'guideline_mayo.jsonl_655.json',
#  'guideline_mayo.jsonl_428.json',
#  'guideline_nice.jsonl_1325.json',
#  'guideline_nice.jsonl_1017.json',
#  'guideline_nice.jsonl_1633.json',
#  'guideline_cma.jsonl_3.json',
#  'guideline_nice.jsonl_1507.json',
#  'guideline_gc.jsonl_138.json',
#  'guideline_mayo.jsonl_413.json',
#  'guideline_gc.jsonl_942.json',
#  'guideline_mayo.jsonl_41.json',
#  'guideline_mayo.jsonl_197.json',
#  'guideline_rch.jsonl_224.json',
#  'guideline_gc.jsonl_763.json',
#  'guideline_nice.jsonl_1472.json',
#  'guideline_gc.jsonl_456.json',
#  'guideline_mayo.jsonl_583.json',
#  'guideline_nice.jsonl_553.json',
#  'guideline_gc.jsonl_333.json',
#  'guideline_nice.jsonl_1341.json',
#  'guideline_mayo.jsonl_108.json',
#  'guideline_rch.jsonl_329.json',
#  'guideline_mayo.jsonl_887.json',
#  'guideline_gc.jsonl_263.json',
#  'guideline_mayo.jsonl_949.json',
#  'guideline_gc.jsonl_147.json',
#  'guideline_mayo.jsonl_922.json',
#  'guideline_idsa.jsonl_20.json',
#  'guideline_mayo.jsonl_469.json',
#  'guideline_nice.jsonl_871.json',
#  'guideline_nice.jsonl_1165.json',
#  'guideline_gc.jsonl_706.json',
#  'guideline_nice.jsonl_181.json',
#  'guideline_nice.jsonl_1514.json',
#  'guideline_mayo.jsonl_905.json',
#  'guideline_usp.jsonl_34.json',
#  'guideline_rch.jsonl_163.json',
#  'guideline_mayo.jsonl_582.json',
#  'guideline_nice.jsonl_1401.json',
#  'guideline_gc.jsonl_250.json',
#  'guideline_rch.jsonl_247.json',
#  'guideline_mayo.jsonl_984.json',
#  'guideline_usp.jsonl_74.json',
#  'guideline_gc.jsonl_358.json',
#  'guideline_mayo.jsonl_641.json',
#  'guideline_nice.jsonl_1385.json',
#  'guideline_mayo.jsonl_261.json',
#  'guideline_mayo.jsonl_953.json',
#  'guideline_gc.jsonl_534.json',
#  'guideline_gc.jsonl_941.json',
#  'guideline_nice.jsonl_1560.json',
#  'guideline_gc.jsonl_730.json',
#  'guideline_gc.jsonl_931.json',
#  'guideline_mayo.jsonl_358.json',
#  'guideline_gc.jsonl_166.json',
#  'guideline_nice.jsonl_1558.json',
#  'guideline_gc.jsonl_157.json',
#  'guideline_gc.jsonl_325.json',
#  'guideline_mayo.jsonl_431.json',
#  'guideline_mayo.jsonl_842.json',
#  'guideline_mayo.jsonl_467.json',
#  'guideline_gc.jsonl_372.json',
#  'guideline_gc.jsonl_746.json',
#  'guideline_gc.jsonl_386.json',
#  'guideline_mayo.jsonl_363.json',
#  'guideline_mayo.jsonl_423.json',
#  'guideline_rch.jsonl_169.json',
#  'guideline_rch.jsonl_63.json',
#  'guideline_gc.jsonl_39.json',
#  'guideline_mayo.jsonl_411.json',
#  'guideline_cdc_diseases.jsonl_28.json',
#  'guideline_rch.jsonl_74.json',
#  'guideline_mayo.jsonl_567.json',
#  'guideline_mayo.jsonl_105.json',
#  'guideline_mayo.jsonl_775.json',
#  'guideline_rch.jsonl_291.json',
#  'guideline_gc.jsonl_850.json',
#  'guideline_mayo.jsonl_1031.json',
#  'guideline_gc.jsonl_350.json',
#  'guideline_gc.jsonl_920.json',
#  'guideline_gc.jsonl_179.json',
#  'guideline_gc.jsonl_835.json',
#  'guideline_usp.jsonl_24.json',
#  'guideline_nice.jsonl_619.json',
#  'guideline_nice.jsonl_552.json',
#  'guideline_gc.jsonl_14.json',
#  'guideline_rch.jsonl_12.json',
#  'guideline_nice.jsonl_1640.json',
#  'guideline_gc.jsonl_73.json',
#  'guideline_mayo.jsonl_486.json',
#  'guideline_mayo.jsonl_34.json',
#  'guideline_mayo.jsonl_975.json',
#  'guideline_mayo.jsonl_1019.json',
#  'guideline_mayo.jsonl_592.json',
#  'guideline_nice.jsonl_352.json',
#  'guideline_mayo.jsonl_139.json',
#  'guideline_nice.jsonl_1494.json',
#  'guideline_rch.jsonl_23.json',
#  'guideline_nice.jsonl_1567.json',
#  'guideline_nice.jsonl_872.json',
#  'guideline_gc.jsonl_565.json',
#  'guideline_mayo.jsonl_994.json',
#  'guideline_aafp.jsonl_50.json',
#  'guideline_gc.jsonl_384.json',
#  'guideline_gc.jsonl_745.json',
#  'guideline_mayo.jsonl_828.json',
#  'guideline_nice.jsonl_488.json',
#  'guideline_gc.jsonl_21.json',
#  'guideline_nice.jsonl_1451.json',
#  'guideline_mayo.jsonl_167.json',
#  'guideline_nice.jsonl_1513.json',
#  'guideline_gc.jsonl_598.json',
#  'guideline_rch.jsonl_15.json',
#  'guideline_gc.jsonl_190.json',
#  'guideline_nice.jsonl_1417.json',
#  'guideline_mayo.jsonl_136.json',
#  'guideline_gc.jsonl_30.json',
#  'guideline_nice.jsonl_510.json',
#  'guideline_gc.jsonl_796.json',
#  'guideline_gc.jsonl_345.json',
#  'guideline_mayo.jsonl_635.json',
#  'guideline_mayo.jsonl_228.json',
#  'guideline_gc.jsonl_526.json',
#  'guideline_mayo.jsonl_683.json',
#  'guideline_nice.jsonl_1027.json',
#  'guideline_gc.jsonl_889.json',
#  'guideline_gc.jsonl_729.json',
#  'guideline_rch.jsonl_292.json',
#  'guideline_nice.jsonl_353.json',
#  'guideline_mayo.jsonl_117.json',
#  'guideline_usp.jsonl_59.json',
#  'guideline_nice.jsonl_1547.json',
#  'guideline_mayo.jsonl_65.json',
#  'guideline_mayo.jsonl_914.json',
#  'guideline_mayo.jsonl_1073.json',
#  'guideline_gc.jsonl_732.json',
#  'guideline_rch.jsonl_78.json',
#  'guideline_gc.jsonl_6.json',
#  'guideline_rch.jsonl_258.json',
#  'guideline_gc.jsonl_123.json',
#  'guideline_mayo.jsonl_626.json',
#  'guideline_aafp.jsonl_34.json',
#  'guideline_mayo.jsonl_545.json',
#  'guideline_nice.jsonl_1050.json',
#  'guideline_gc.jsonl_491.json',
#  'guideline_nice.jsonl_1436.json',
#  'guideline_gc.jsonl_413.json',
#  'guideline_mayo.jsonl_472.json',
#  'guideline_nice.jsonl_796.json',
#  'guideline_nice.jsonl_1295.json',
#  'guideline_nice.jsonl_1564.json',
#  'guideline_cdc_diseases.jsonl_35.json',
#  'guideline_gc.jsonl_160.json',
#  'guideline_gc.jsonl_256.json',
#  'guideline_usp.jsonl_81.json',
#  'guideline_mayo.jsonl_414.json',
#  'guideline_mayo.jsonl_420.json',
#  'guideline_mayo.jsonl_1.json',
#  'guideline_mayo.jsonl_475.json',
#  'guideline_nice.jsonl_928.json',
#  'guideline_nice.jsonl_300.json',
#  'guideline_gc.jsonl_406.json',
#  'guideline_rch.jsonl_250.json',
#  'guideline_rch.jsonl_58.json',
#  'guideline_nice.jsonl_587.json',
#  'guideline_rch.jsonl_69.json',
#  'guideline_gc.jsonl_756.json',
#  'guideline_gc.jsonl_383.json',
#  'guideline_mayo.jsonl_611.json',
#  'guideline_aafp.jsonl_12.json',
#  'guideline_nice.jsonl_945.json',
#  'guideline_mayo.jsonl_895.json',
#  'guideline_nice.jsonl_1539.json',
#  'guideline_gc.jsonl_465.json',
#  'guideline_gc.jsonl_270.json',
#  'guideline_gc.jsonl_83.json',
#  'guideline_rch.jsonl_157.json',
#  'guideline_mayo.jsonl_496.json',
#  'guideline_aafp.jsonl_7.json',
#  'guideline_nice.jsonl_1103.json',
#  'guideline_mayo.jsonl_226.json',
#  'guideline_nice.jsonl_1546.json',
#  'guideline_mayo.jsonl_333.json',
#  'guideline_usp.jsonl_83.json',
#  'guideline_nice.jsonl_1268.json',
#  'guideline_gc.jsonl_408.json',
#  'guideline_rch.jsonl_93.json',
#  'guideline_rch.jsonl_243.json',
#  'guideline_nice.jsonl_140.json',
#  'guideline_nice.jsonl_1608.json',
#  'guideline_gc.jsonl_349.json',
#  'guideline_rch.jsonl_255.json',
#  'guideline_nice.jsonl_601.json',
#  'guideline_nice.jsonl_36.json',
#  'guideline_mayo.jsonl_923.json',
#  'guideline_cma.jsonl_8.json',
#  'guideline_nice.jsonl_1460.json',
#  'guideline_mayo.jsonl_794.json',
#  'guideline_gc.jsonl_864.json',
#  'guideline_mayo.jsonl_365.json',
#  'guideline_gc.jsonl_468.json',
#  'guideline_gc.jsonl_90.json',
#  'guideline_nice.jsonl_841.json',
#  'guideline_mayo.jsonl_308.json',
#  'guideline_mayo.jsonl_558.json',
#  'guideline_nice.jsonl_12.json',
#  'guideline_mayo.jsonl_155.json',
#  'guideline_nice.jsonl_359.json',
#  'guideline_rch.jsonl_235.json',
#  'guideline_mayo.jsonl_170.json',
#  'guideline_gc.jsonl_654.json',
#  'guideline_cdc_diseases.jsonl_8.json',
#  'guideline_rch.jsonl_180.json',
#  'guideline_mayo.jsonl_837.json',
#  'guideline_mayo.jsonl_209.json',
#  'guideline_gc.jsonl_694.json',
#  'guideline_gc.jsonl_715.json',
#  'guideline_mayo.jsonl_771.json',
#  'guideline_nice.jsonl_1340.json',
#  'guideline_mayo.jsonl_1092.json',
#  'guideline_mayo.jsonl_203.json',
#  'guideline_mayo.jsonl_750.json',
#  'guideline_mayo.jsonl_615.json',
#  'guideline_gc.jsonl_1.json',
#  'guideline_mayo.jsonl_956.json',
#  'guideline_nice.jsonl_1347.json',
#  'guideline_mayo.jsonl_921.json',
#  'guideline_gc.jsonl_570.json',
#  'guideline_mayo.jsonl_1095.json',
#  'guideline_mayo.jsonl_749.json',
#  'guideline_gc.jsonl_307.json',
#  'guideline_mayo.jsonl_344.json',
#  'guideline_gc.jsonl_319.json',
#  'guideline_gc.jsonl_649.json',
#  'guideline_usp.jsonl_70.json',
#  'guideline_gc.jsonl_185.json',
#  'guideline_gc.jsonl_10.json',
#  'guideline_gc.jsonl_516.json',
#  'guideline_cdc_diseases.jsonl_37.json',
#  'guideline_rch.jsonl_86.json',
#  'guideline_mayo.jsonl_868.json',
#  'guideline_nice.jsonl_362.json',
#  'guideline_mayo.jsonl_9.json',
#  'guideline_gc.jsonl_927.json',
#  'guideline_gc.jsonl_822.json',
#  'guideline_nice.jsonl_1593.json',
#  'guideline_mayo.jsonl_408.json',
#  'guideline_rch.jsonl_42.json',
#  'guideline_nice.jsonl_1639.json',
#  'guideline_mayo.jsonl_885.json',
#  'guideline_rch.jsonl_77.json',
#  'guideline_nice.jsonl_1537.json',
#  'guideline_mayo.jsonl_791.json',
#  'guideline_mayo.jsonl_677.json',
#  'guideline_nice.jsonl_1555.json',
#  'guideline_gc.jsonl_536.json',
#  'guideline_nice.jsonl_708.json',
#  'guideline_gc.jsonl_134.json',
#  'guideline_mayo.jsonl_440.json',
#  'guideline_nice.jsonl_684.json',
#  'guideline_nice.jsonl_751.json',
#  'guideline_idsa.jsonl_40.json',
#  'guideline_gc.jsonl_550.json',
#  'guideline_rch.jsonl_178.json',
#  'guideline_nice.jsonl_1526.json',
#  'guideline_nice.jsonl_1625.json',
#  'guideline_mayo.jsonl_663.json',
#  'guideline_cdc_diseases.jsonl_43.json',
#  'guideline_gc.jsonl_567.json',
#  'guideline_nice.jsonl_134.json',
#  'guideline_mayo.jsonl_342.json',
#  'guideline_mayo.jsonl_91.json',
#  'guideline_mayo.jsonl_1033.json',
#  'guideline_mayo.jsonl_269.json',
#  'guideline_nice.jsonl_1109.json',
#  'guideline_gc.jsonl_508.json',
#  'guideline_mayo.jsonl_818.json',
#  'guideline_nice.jsonl_547.json',
#  'guideline_mayo.jsonl_503.json',
#  'guideline_gc.jsonl_616.json',
#  'guideline_mayo.jsonl_557.json',
#  'guideline_nice.jsonl_1361.json',
#  'guideline_mayo.jsonl_980.json',
#  'guideline_mayo.jsonl_248.json',
#  'guideline_nice.jsonl_1475.json',
#  'guideline_gc.jsonl_28.json',
#  'guideline_gc.jsonl_70.json',
#  'guideline_rch.jsonl_322.json',
#  'guideline_gc.jsonl_885.json',
#  'guideline_mayo.jsonl_904.json',
#  'guideline_gc.jsonl_780.json',
#  'guideline_gc.jsonl_165.json',
#  'guideline_mayo.jsonl_1032.json',
#  'guideline_mayo.jsonl_533.json',
#  'guideline_nice.jsonl_1532.json',
#  'guideline_nice.jsonl_562.json',
#  'guideline_gc.jsonl_371.json',
#  'guideline_mayo.jsonl_265.json',
#  'guideline_mayo.jsonl_297.json',
#  'guideline_mayo.jsonl_501.json',
#  'guideline_mayo.jsonl_359.json',
#  'guideline_gc.jsonl_844.json',
#  'guideline_nice.jsonl_1037.json',
#  'guideline_mayo.jsonl_232.json',
#  'guideline_mayo.jsonl_652.json',
#  'guideline_gc.jsonl_521.json',
#  'guideline_nice.jsonl_1010.json',
#  'guideline_rch.jsonl_217.json',
#  'guideline_nice.jsonl_284.json',
#  'guideline_usp.jsonl_65.json',
#  'guideline_nice.jsonl_1139.json',
#  'guideline_nice.jsonl_983.json',
#  'guideline_nice.jsonl_1601.json',
#  'guideline_gc.jsonl_233.json',
#  'guideline_gc.jsonl_352.json',
#  'guideline_nice.jsonl_1142.json',
#  'guideline_nice.jsonl_1572.json',
#  'guideline_mayo.jsonl_328.json',
#  'guideline_mayo.jsonl_902.json',
#  'guideline_mayo.jsonl_1090.json',
#  'guideline_mayo.jsonl_919.json',
#  'guideline_gc.jsonl_295.json',
#  'guideline_nice.jsonl_1324.json',
#  'guideline_cdc_diseases.jsonl_38.json',
#  'guideline_rch.jsonl_273.json',
#  'guideline_gc.jsonl_314.json',
#  'guideline_mayo.jsonl_383.json',
#  'guideline_usp.jsonl_76.json',
#  'guideline_rch.jsonl_39.json',
#  'guideline_usp.jsonl_78.json',
#  'guideline_mayo.jsonl_594.json',
#  'guideline_gc.jsonl_628.json',
#  'guideline_nice.jsonl_1412.json',
#  'guideline_mayo.jsonl_509.json',
#  'guideline_rch.jsonl_54.json',
#  'guideline_mayo.jsonl_345.json',
#  'guideline_mayo.jsonl_309.json',
#  'guideline_usp.jsonl_49.json',
#  'guideline_rch.jsonl_70.json',
#  'guideline_nice.jsonl_1115.json',
#  'guideline_gc.jsonl_702.json',
#  'guideline_idsa.jsonl_36.json',
#  'guideline_gc.jsonl_735.json',
#  'guideline_gc.jsonl_538.json',
#  'guideline_idsa.jsonl_26.json',
#  'guideline_gc.jsonl_900.json',
#  'guideline_gc.jsonl_870.json',
#  'guideline_gc.jsonl_342.json',
#  'guideline_gc.jsonl_656.json',
#  'guideline_nice.jsonl_1462.json',
#  'guideline_gc.jsonl_753.json',
#  'guideline_gc.jsonl_716.json',
#  'guideline_gc.jsonl_858.json',
#  'guideline_mayo.jsonl_52.json',
#  'guideline_gc.jsonl_121.json',
#  'guideline_gc.jsonl_907.json',
#  'guideline_nice.jsonl_1214.json',
#  'guideline_cdc_diseases.jsonl_41.json',
#  'guideline_mayo.jsonl_439.json',
#  'guideline_mayo.jsonl_140.json',
#  'guideline_mayo.jsonl_60.json',
#  'guideline_nice.jsonl_1448.json',
#  'guideline_gc.jsonl_279.json',
#  'guideline_gc.jsonl_11.json',
#  'guideline_mayo.jsonl_22.json',
#  'guideline_mayo.jsonl_424.json',
#  'guideline_mayo.jsonl_116.json',
#  'guideline_cma.jsonl_29.json',
#  'guideline_mayo.jsonl_343.json',
#  'guideline_rch.jsonl_116.json',
#  'guideline_rch.jsonl_59.json',
#  'guideline_mayo.jsonl_883.json',
#  'guideline_usp.jsonl_8.json',
#  'guideline_nice.jsonl_877.json',
#  'guideline_nice.jsonl_1164.json',
#  'guideline_mayo.jsonl_121.json',
#  'guideline_nice.jsonl_1655.json',
#  'guideline_gc.jsonl_460.json',
#  'guideline_mayo.jsonl_619.json',
#  'guideline_rch.jsonl_35.json',
#  'guideline_gc.jsonl_433.json',
#  'guideline_mayo.jsonl_375.json',
#  'guideline_nice.jsonl_1114.json',
#  'guideline_gc.jsonl_943.json',
#  'guideline_mayo.jsonl_550.json',
#  'guideline_nice.jsonl_1438.json',
#  'guideline_nice.jsonl_1502.json',
#  'guideline_cdc_diseases.jsonl_24.json',
#  'guideline_mayo.jsonl_889.json',
#  'guideline_mayo.jsonl_508.json',
#  'guideline_gc.jsonl_117.json',
#  'guideline_nice.jsonl_1123.json',
#  'guideline_gc.jsonl_38.json',
#  'guideline_gc.jsonl_597.json',
#  'guideline_nice.jsonl_1357.json',
#  'guideline_mayo.jsonl_811.json',
#  'guideline_nice.jsonl_1265.json',
#  'guideline_mayo.jsonl_368.json',
#  'guideline_rch.jsonl_102.json',
#  'guideline_aafp.jsonl_17.json',
#  'guideline_nice.jsonl_489.json',
#  'guideline_nice.jsonl_491.json',
#  'guideline_nice.jsonl_1606.json',
#  'guideline_rch.jsonl_171.json',
#  'guideline_nice.jsonl_1647.json',
#  'guideline_rch.jsonl_152.json',
#  'guideline_usp.jsonl_55.json',
#  'guideline_rch.jsonl_237.json',
#  'guideline_nice.jsonl_1036.json',
#  'guideline_gc.jsonl_863.json',
#  'guideline_nice.jsonl_1538.json',
#  'guideline_gc.jsonl_467.json',
#  'guideline_gc.jsonl_370.json',
#  'guideline_mayo.jsonl_455.json',
#  'guideline_gc.jsonl_222.json',
#  'guideline_gc.jsonl_811.json',
#  'guideline_gc.jsonl_916.json',
#  'guideline_gc.jsonl_96.json',
#  'guideline_nice.jsonl_640.json',
#  'guideline_mayo.jsonl_470.json',
#  'guideline_aafp.jsonl_6.json',
#  'guideline_mayo.jsonl_317.json',
#  'guideline_gc.jsonl_13.json',
#  'guideline_mayo.jsonl_797.json',
#  'guideline_mayo.jsonl_860.json',
#  'guideline_gc.jsonl_129.json',
#  'guideline_mayo.jsonl_133.json',
#  'guideline_nice.jsonl_1581.json',
#  'guideline_rch.jsonl_166.json',
#  'guideline_mayo.jsonl_450.json',
#  'guideline_mayo.jsonl_490.json',
#  'guideline_gc.jsonl_253.json',
#  'guideline_nice.jsonl_1321.json',
#  'guideline_gc.jsonl_906.json',
#  'guideline_mayo.jsonl_352.json',
#  'guideline_rch.jsonl_300.json',
#  'guideline_mayo.jsonl_1003.json',
#  'guideline_gc.jsonl_622.json',
#  'guideline_gc.jsonl_105.json',
#  'guideline_mayo.jsonl_113.json',
#  'guideline_mayo.jsonl_362.json',
#  'guideline_nice.jsonl_464.json',
#  'guideline_gc.jsonl_451.json',
#  'guideline_mayo.jsonl_432.json',
#  'guideline_gc.jsonl_590.json',
#  'guideline_rch.jsonl_349.json',
#  'guideline_mayo.jsonl_944.json',
#  'guideline_mayo.jsonl_75.json',
#  'guideline_gc.jsonl_619.json',
#  'guideline_mayo.jsonl_625.json',
#  'guideline_gc.jsonl_770.json',
#  'guideline_mayo.jsonl_47.json',
#  'guideline_nice.jsonl_1489.json',
#  'guideline_mayo.jsonl_329.json',
#  'guideline_gc.jsonl_743.json',
#  'guideline_gc.jsonl_428.json',
#  'guideline_usp.jsonl_51.json',
#  'guideline_gc.jsonl_120.json',
#  'guideline_mayo.jsonl_401.json',
#  'guideline_mayo.jsonl_215.json',
#  'guideline_nice.jsonl_203.json',
#  'guideline_nice.jsonl_1183.json',
#  'guideline_gc.jsonl_264.json',
#  'guideline_gc.jsonl_112.json',
#  'guideline_mayo.jsonl_856.json',
#  'guideline_gc.jsonl_836.json',
#  'guideline_gc.jsonl_840.json',
#  'guideline_nice.jsonl_1461.json',
#  'guideline_nice.jsonl_581.json',
#  'guideline_nice.jsonl_1269.json',
#  'guideline_mayo.jsonl_913.json',
#  'guideline_nice.jsonl_210.json',
#  'guideline_idsa.jsonl_2.json',
#  'guideline_nice.jsonl_1237.json',
#  'guideline_mayo.jsonl_85.json',
#  'guideline_usp.jsonl_19.json',
#  'guideline_mayo.jsonl_323.json',
#  'guideline_nice.jsonl_1277.json',
#  'guideline_nice.jsonl_200.json',
#  'guideline_gc.jsonl_798.json',
#  'guideline_mayo.jsonl_386.json',
#  'guideline_mayo.jsonl_668.json',
#  'guideline_mayo.jsonl_77.json',
#  'guideline_gc.jsonl_769.json',
#  'guideline_cdc_diseases.jsonl_13.json',
#  'guideline_nice.jsonl_342.json',
#  'guideline_mayo.jsonl_520.json',
#  'guideline_gc.jsonl_221.json',
#  'guideline_mayo.jsonl_1006.json',
#  'guideline_mayo.jsonl_725.json',
#  'guideline_rch.jsonl_71.json',
#  'guideline_mayo.jsonl_456.json',
#  'guideline_mayo.jsonl_1023.json',
#  'guideline_mayo.jsonl_27.json',
#  'guideline_nice.jsonl_994.json',
#  'guideline_nice.jsonl_17.json',
#  'guideline_nice.jsonl_955.json',
#  'guideline_mayo.jsonl_177.json',
#  'guideline_rch.jsonl_164.json',
#  'guideline_mayo.jsonl_577.json',
#  'guideline_mayo.jsonl_528.json',
#  'guideline_mayo.jsonl_482.json',
#  'guideline_mayo.jsonl_561.json',
#  'guideline_nice.jsonl_1120.json',
#  'guideline_mayo.jsonl_751.json',
#  'guideline_gc.jsonl_950.json',
#  'guideline_gc.jsonl_807.json',
#  'guideline_mayo.jsonl_808.json',
#  'guideline_gc.jsonl_290.json',
#  'guideline_nice.jsonl_674.json',
#  'guideline_gc.jsonl_804.json',
#  'guideline_mayo.jsonl_844.json',
#  'guideline_mayo.jsonl_114.json',
#  'guideline_nice.jsonl_887.json',
#  'guideline_gc.jsonl_196.json',
#  'guideline_rch.jsonl_52.json',
#  'guideline_gc.jsonl_496.json',
#  'guideline_mayo.jsonl_179.json',
#  'guideline_gc.jsonl_135.json',
#  'guideline_usp.jsonl_44.json',
#  'guideline_nice.jsonl_1508.json',
#  'guideline_nice.jsonl_1167.json',
#  'guideline_nice.jsonl_1656.json',
#  'guideline_mayo.jsonl_349.json',
#  'guideline_mayo.jsonl_42.json',
#  'guideline_mayo.jsonl_498.json',
#  'guideline_mayo.jsonl_410.json',
#  'guideline_nice.jsonl_1320.json',
#  'guideline_rch.jsonl_242.json',
#  'guideline_gc.jsonl_725.json',
#  'guideline_mayo.jsonl_206.json',
#  'guideline_gc.jsonl_215.json',
#  'guideline_gc.jsonl_187.json',
#  'guideline_mayo.jsonl_1085.json',
#  'guideline_rch.jsonl_335.json',
#  'guideline_gc.jsonl_877.json',
#  'guideline_mayo.jsonl_1088.json',
#  'guideline_gc.jsonl_35.json',
#  'guideline_mayo.jsonl_505.json',
#  'guideline_mayo.jsonl_653.json',
#  'guideline_nice.jsonl_645.json',
#  'guideline_gc.jsonl_704.json',
#  'guideline_nice.jsonl_1305.json',
#  'guideline_nice.jsonl_574.json',
#  'guideline_aafp.jsonl_37.json',
#  'guideline_mayo.jsonl_278.json',
#  'guideline_mayo.jsonl_965.json',
#  'guideline_nice.jsonl_962.json',
#  'guideline_mayo.jsonl_907.json']

# %%
import json
content = []
for file in onlyfiles:
    with open(patient_folder+file) as f:
        a = json.load(f)
        for label, text in a.items():
            label = label[:-2]
            content += [(text, label, file)]
            print(file)
# Out:
# guideline_gc.jsonl_435.json
# guideline_gc.jsonl_435.json
# guideline_gc.jsonl_435.json
# guideline_mayo.jsonl_682.json
# guideline_mayo.jsonl_682.json
# guideline_mayo.jsonl_682.json
# guideline_mayo.jsonl_310.json
# guideline_mayo.jsonl_310.json
# guideline_mayo.jsonl_310.json
# guideline_gc.jsonl_709.json
# guideline_gc.jsonl_709.json
# guideline_gc.jsonl_709.json
# guideline_gc.jsonl_946.json
# guideline_gc.jsonl_946.json
# guideline_gc.jsonl_946.json
# guideline_nice.jsonl_858.json
# guideline_nice.jsonl_858.json
# guideline_nice.jsonl_858.json
# guideline_gc.jsonl_414.json
# guideline_gc.jsonl_414.json
# guideline_gc.jsonl_414.json
# guideline_rch.jsonl_265.json
# guideline_rch.jsonl_265.json
# guideline_rch.jsonl_265.json
# guideline_cdc_diseases.jsonl_15.json
# guideline_mayo.jsonl_410.json
# guideline_nice.jsonl_1320.json
# guideline_nice.jsonl_1320.json
# guideline_nice.jsonl_1320.json
# guideline_rch.jsonl_242.json
# guideline_rch.jsonl_242.json
# guideline_rch.jsonl_242.json
# guideline_gc.jsonl_725.json
# guideline_gc.jsonl_725.json
# guideline_gc.jsonl_725.json
# guideline_mayo.jsonl_206.json
# guideline_mayo.jsonl_206.json
# guideline_mayo.jsonl_206.json
# guideline_gc.jsonl_215.json
# guideline_gc.jsonl_215.json
# guideline_gc.jsonl_215.json
# guideline_gc.jsonl_187.json
# guideline_gc.jsonl_187.json
# guideline_gc.jsonl_187.json
# guideline_mayo.jsonl_1085.json
# guideline_mayo.jsonl_1085.json
# guideline_mayo.jsonl_1085.json
# guideline_rch.jsonl_335.json
# guideline_rch.jsonl_335.json
# guideline_rch.jsonl_335.json
# guideline_gc.jsonl_877.json
# guideline_gc.jsonl_877.json
# guideline_gc.jsonl_877.json
# guideline_mayo.jsonl_1088.json
# guideline_mayo.jsonl_1088.json
# guideline_mayo.jsonl_1088.json
# guideline_gc.jsonl_35.json
# guideline_gc.jsonl_35.json
# guideline_gc.jsonl_35.json
# guideline_mayo.jsonl_505.json
# guideline_mayo.jsonl_505.json
# guideline_mayo.jsonl_505.json
# guideline_mayo.jsonl_653.json
# guideline_mayo.jsonl_653.json
# guideline_mayo.jsonl_653.json
# guideline_nice.jsonl_645.json
# guideline_nice.jsonl_645.json
# guideline_nice.jsonl_645.json
# guideline_gc.jsonl_704.json
# guideline_gc.jsonl_704.json
# guideline_gc.jsonl_704.json
# guideline_nice.jsonl_1305.json
# guideline_nice.jsonl_1305.json
# guideline_nice.jsonl_1305.json
# guideline_nice.jsonl_574.json
# guideline_nice.jsonl_574.json
# guideline_nice.jsonl_574.json
# guideline_aafp.jsonl_37.json
# guideline_aafp.jsonl_37.json
# guideline_aafp.jsonl_37.json
# guideline_mayo.jsonl_278.json
# guideline_mayo.jsonl_278.json
# guideline_mayo.jsonl_278.json
# guideline_mayo.jsonl_965.json
# guideline_mayo.jsonl_965.json
# guideline_mayo.jsonl_965.json
# guideline_nice.jsonl_962.json
# guideline_nice.jsonl_962.json
# guideline_nice.jsonl_962.json
# guideline_mayo.jsonl_907.json
# guideline_mayo.jsonl_907.json
# guideline_mayo.jsonl_907.json

# %%
content[0]
# Out:
# ("Patient Description 1:\nA 6-year-old patient, with no significant medical history, was brought in by their parents for an ophthalmologic evaluation. The child has been experiencing a persistent reduced visual acuity in one eye, which the parents noticed during daily activities such as reading or watching television. Despite interventions, including adequate corrective lenses, the visual acuity issue persists. The child also exhibits poor depth perception, often struggling with tasks that require hand-eye coordination. Furthermore, the parents have observed the child squinting or closing one eye to see better, particularly when engaged in activities that demand focused visual attention. The diagnostic process may be influenced by the child's age and level of cooperation during the assessment.",
#  'Amblyopia',
#  'guideline_gc.jsonl_435.json')

# %%
def remove_newlines(text):
    return text.replace('\n', ' ')

def save_to_file(text, filename):
    with open(filename, 'w') as file:
        file.write(text)

# %%
def run_mistral_with_input(input_text, timeout):
    process = subprocess.Popen(['ollama', 'run', 'mistral'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    try:
        stdout, stderr = process.communicate(input_text, timeout=timeout)
        
        if process.returncode != 0:
            print(f"Error executing command: {stderr}")
            return None

    except subprocess.TimeoutExpired:
        process.terminate()
        process.wait()
        print("Process timed out and was terminated.")
        return None

    finally:
        if process.poll() is None: 
            process.terminate()
        process.wait()
    return stdout

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model_name = "mistralai/Mistral-7B-v0.1"
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/etien/Documents/EPFLcourses/MA3/Meditron/MiniMeditron-Prototype/data/structure/from prompt to symptoms.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/home/etien/Documents/EPFLcourses/MA3/Meditron/MiniMeditron-Prototype/data/structure/from%20prompt%20to%20symptoms.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from transformers import AutoModelForCausalLM, AutoTokenizer
#       <a href='vscode-notebook-cell:/home/etien/Documents/EPFLcourses/MA3/Meditron/MiniMeditron-Prototype/data/structure/from%20prompt%20to%20symptoms.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> model_name = "mistralai/Mistral-7B-v0.1"
# ----> <a href='vscode-notebook-cell:/home/etien/Documents/EPFLcourses/MA3/Meditron/MiniMeditron-Prototype/data/structure/from%20prompt%20to%20symptoms.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> model = AutoModelForCausalLM.from_pretrained(model_name)
#       <a href='vscode-notebook-cell:/home/etien/Documents/EPFLcourses/MA3/Meditron/MiniMeditron-Prototype/data/structure/from%20prompt%20to%20symptoms.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:566, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564 elif type(config) in cls._model_mapping.keys():
#     565     model_class = _get_model_class(config, cls._model_mapping)
# --> 566     return model_class.from_pretrained(
#     567         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568     )
#     569 raise ValueError(
#     570     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     571     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     572 )
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:3128, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3125 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3126 if is_sharded:
#    3127     # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3128     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3129         pretrained_model_name_or_path,
#    3130         resolved_archive_file,
#    3131         cache_dir=cache_dir,
#    3132         force_download=force_download,
#    3133         proxies=proxies,
#    3134         resume_download=resume_download,
#    3135         local_files_only=local_files_only,
#    3136         token=token,
#    3137         user_agent=user_agent,
#    3138         revision=revision,
#    3139         subfolder=subfolder,
#    3140         _commit_hash=commit_hash,
#    3141     )
#    3143 if (
#    3144     is_safetensors_available()
#    3145     and isinstance(resolved_archive_file, str)
#    3146     and resolved_archive_file.endswith(".safetensors")
#    3147 ):
#    3148     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/utils/hub.py:1052, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1049 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1050     try:
#    1051         # Load from URL
# -> 1052         cached_filename = cached_file(
#    1053             pretrained_model_name_or_path,
#    1054             shard_filename,
#    1055             cache_dir=cache_dir,
#    1056             force_download=force_download,
#    1057             proxies=proxies,
#    1058             resume_download=resume_download,
#    1059             local_files_only=local_files_only,
#    1060             token=token,
#    1061             user_agent=user_agent,
#    1062             revision=revision,
#    1063             subfolder=subfolder,
#    1064             _commit_hash=_commit_hash,
#    1065         )
#    1066     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1067     # we don't have to catch them here.
#    1068     except EntryNotFoundError:
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/utils/hub.py:430, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     427 user_agent = http_user_agent(user_agent)
#     428 try:
#     429     # Load from URL or cache if already cached
# --> 430     resolved_file = hf_hub_download(
#     431         path_or_repo_id,
#     432         filename,
#     433         subfolder=None if len(subfolder) == 0 else subfolder,
#     434         repo_type=repo_type,
#     435         revision=revision,
#     436         cache_dir=cache_dir,
#     437         user_agent=user_agent,
#     438         force_download=force_download,
#     439         proxies=proxies,
#     440         resume_download=resume_download,
#     441         token=token,
#     442         local_files_only=local_files_only,
#     443     )
#     444 except GatedRepoError as e:
#     445     raise EnvironmentError(
#     446         "You are trying to access a gated repo.\nMake sure to request access at "
#     447         f"https://huggingface.co/{path_or_repo_id} and pass a token having permission to this repo either "
#     448         "by logging in with `huggingface-cli login` or by passing `token=<your_token>`."
#     449     ) from e
#
# File ~/miniconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1431, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, endpoint, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1428         if local_dir is not None:
#    1429             _check_disk_space(expected_size, local_dir)
# -> 1431     http_get(
#    1432         url_to_download,
#    1433         temp_file,
#    1434         proxies=proxies,
#    1435         resume_size=resume_size,
#    1436         headers=headers,
#    1437         expected_size=expected_size,
#    1438     )
#    1440 if local_dir is None:
#    1441     logger.info(f"Storing {url} in cache at {blob_path}")
#
# File ~/miniconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:551, in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries, expected_size)
#     541     displayed_name = f"(…){displayed_name[-20:]}"
#     543 progress = tqdm(
#     544     unit="B",
#     545     unit_scale=True,
#    (...)
#     549     disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     550 )
# --> 551 for chunk in r.iter_content(chunk_size=10 * 1024 * 1024):
#     552     if chunk:  # filter out keep-alive new chunks
#     553         progress.update(len(chunk))
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniconda3/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/miniconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for (text,label, file) in content:
    input_text = " Here is a patient description : " +text+ """
Fill the following structure accordingly. Don't change it.
If the information is not given, don't write anything, leave it as an empty section.
If an information is true for multiple symptoms, repeat the information.
Only answer with the filled structure.

{
  "symptoms": [
    {
      "name of the symptom": "",
      "intensity of symptom": "",
      "specific attributes of the symptom": {
        "location": "",
        "size": "",
        "color": "",
        "frequency": ""
      },
      "When did the symptom appear ": "",
      "previous treatments": "",
      "reaction to previous treaments"
      "behaviour affecting the symptom": ""
    }
  ],
  "socio economic context": {
  },
  "geographic_context": {
      "recent travels": "",
      "level of care": ""
  },
  "physiological context": {
  
  },
  "psychological context": {
  
  },
  "personal medical_history": {
  
  },
  "family medical_history": {
  
  },
  "current medication": {

  },
  "lifestyle factors": {
  
  },
  "results of recent medical tests": {
  
  }
}
<END>
"""

    #input_text = remove_newlines(input_text)
    
    device = "cpu"
    
    model_inputs = tokenizer([input_text], return_tensors="pt").to(device)

    model.to(device)

    generated_ids = model.generate(**model_inputs, max_new_tokens=100, do_sample=True)

    response = tokenizer.batch_decode(generated_ids)[0]
    
    #response = run_mistral_with_input(input_text, 60 * 5)
    print(response)
    if response:
        with open("train/structured_patient/" + file[:-4], "w") as file:
            file.write(response)
        print("Mistral's response saved to response.txt")
# Out:
# >>>  Here is a patient description :     Patient A, a 45-year-old male, presents with a history of chronic pain in the left lower extremity, which he attributes to a previous injury sustained during a sporting activity. The pain is described as persistent, scoring an average of 7/10 on the visual analog scale, and has been minimally responsive to oral analgesics and physical therapy. Additionally, he experiences episodes of sharp shooting pain radiating down his left leg. Physical examination reveals sensory deficits and reduced proprioception in the affected limb. Given the patient's chronic pain and the inadequacy of conventional therapies, there is an indication for the evaluation of regional nerve block as a management strategy. The diagnostic and treatment decisions will be influenced by the clinician's experience in administering regional nerve blocks, training in ultrasound guidance techniques, and the quality of available ultrasound equipment. Fill the following structure accordingly. Don't change it. If the information is not given, don't write anything, leave it as an empty section. If an information is true for multiple symptoms, repeat the information. Only answer with the filled structure.  {   "symptoms": [     {       "name of the symptom": "",       "intensity of symptom": "",       "specific attributes of the symptom": {         "location": "",         "size": "",         "color": "",         "frequency": ""       },       "When did the symptom appear ": "",       "previous treatments": "",       "reaction to previous treaments"       "behaviour affecting the symptom": ""     }   ],   "socio economic context": {   },   "geographic_context": {       "recent travels": "",       "level of care": ""   },   "physiological context": {      },   "psychological context": {      },   "personal medical_history": {      },   "family medical_history": {      },   "current medication": {    },   "lifestyle factors": {      },   "results of recent medical tests": {      } } <END>
# {
#   "symptoms": [
#     {
#       "name of the symptom": "Chronic pain in left lower extremity",
#       "intensity of symptom": "7/10",
#       "specific attributes of the symptom": {
#         "location": "Left lower extremity"
#       },
#       "When did the symptom appear": "",
#       "previous treatments": "Oral analgesics and physical therapy",
#       "reaction to previous treaments": "Minimally responsive"
#     }
#   ],
#   "socio economic context": {},
#   "geographic_context": {
#     "recent travels": "",
#     "level of care": ""
#   },
#   "physiological context": {},
#   "psychological context": {},
#   "personal medical_history": {},
#   "family medical_history": {},
#   "current medication": {},
#   "lifestyle factors": {},
#   "results of recent medical tests": {}
# }
#
#
# Mistral's response saved to response.txt
# >>>  Here is a patient description :     Patient B, a 60-year-old female, is scheduled for elective orthopedic surgery on her right knee. She presents with concerns regarding perioperative pain management. The patient is anxious about experiencing postoperative pain, which she rates as 8/10 in intensity based on her previous surgical experiences. She is motivated to have effective anaesthesia and analgesia during and after the procedure to ensure a smoother recovery. Given the nature of her upcoming surgery and the importance of optimized pain control, the use of regional nerve block is being considered as part of her anesthetic and analgesic management plan. The decision-making process will depend on the clinician's proficiency in regional nerve block administration, training in ultrasound guidance techniques, and the quality of available ultrasound equipment. Fill the following structure accordingly. Don't change it. If the information is not given, don't write anything, leave it as an empty section. If an information is true for multiple symptoms, repeat the information. Only answer with the filled structure.  {   "symptoms": [     {       "name of the symptom": "",       "intensity of symptom": "",       "specific attributes of the symptom": {         "location": "",         "size": "",         "color": "",         "frequency": ""       },       "When did the symptom appear ": "",       "previous treatments": "",       "reaction to previous treaments"       "behaviour affecting the symptom": ""     }   ],   "socio economic context": {   },   "geographic_context": {       "recent travels": "",       "level of care": ""   },   "physiological context": {      },   "psychological context": {      },   "personal medical_history": {      },   "family medical_history": {      },   "current medication": {    },   "lifestyle factors": {      },   "results of recent medical tests": {      } } <END>
# {
#     "symptoms": [
#         {
#             "name of the symptom": "perioperative pain",
#             "intensity of symptom": "8/10",
#             "specific attributes of the symptom": {
#                 "location": "right knee",
#                 "size": "",
#                 "color": "",
#                 "frequency": "persistent"
#             },
#             "When did the symptom appear": "presenting patient",
#             "previous treatments": "motivated to have effective anaesthesia and analgesia during and after procedure",
#             "reaction to previous treaments": "anxious about experiencing postoperative pain"
#         }
#     ],
#     "socio economic context": {
#     },
#     "geographic_context": {
#        "recent travels": "",
#        "level of care": ""
#     },
#     "physiological context": {
#     },
#     "psychological context": {
#         "behaviour affecting the symptom": "anxious about experiencing postoperative pain"
#     },
#     "personal medical_history": {
#     },
#     "family medical_history": {
#     },
#     "current medication": {
#     },
#     "lifestyle factors": {
#     },
#     "results of recent medical tests": {
#     }
# }
#
#
# Mistral's response saved to response.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 58
#       2     input_text = " Here is a patient description : " +text+ """
#       3 Fill the following structure accordingly. Don't change it.
#       4 If the information is not given, don't write anything, leave it as an empty section.
#    (...)
#      53 <END>
#      54 """
#      56     input_text = remove_newlines(input_text)
# ---> 58     response = run_mistral_with_input(input_text, 60 * 5)
#      59     print(response)
#      60     if response:
#
# Cell In[30], line 5, in run_mistral_with_input(input_text, timeout)
#       2 process = subprocess.Popen(['ollama', 'run', 'mistral'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
#       4 try:
# ----> 5     stdout, stderr = process.communicate(input_text, timeout=timeout)
#       7     if process.returncode != 0:
#       8         print(f"Error executing command: {stderr}")
#
# File ~/miniconda3/envs/bastienv/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/envs/bastienv/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#    2101     self._check_timeout(endtime, orig_timeout,
#    2102                         stdout, stderr,
#    2103                         skip_check_and_raise=True)
#    2104     raise RuntimeError(  # Impossible :)
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#    2106         'failed to raise TimeoutExpired.')
# -> 2108 ready = selector.select(timeout)
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#    2112 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/envs/bastienv/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
run_mistral_with_input("Salut ?", timeout = 60)
# Out:
# '>>> Salut ?\nSalut! Comment allez-vous ?\n\n'
